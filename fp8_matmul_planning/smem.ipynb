# %%
bk_stages = 2
c_stages = 1

def get_smem_kilobytes(BM,BN,BK,bk_stages,c_stages): 
  As_bytes = BM*BK*2 
  Bs_bytes = BK*BN*2
  Cs_bytes = 4*BM*BN
  total_bytes = (bk_stages*(As_bytes+Bs_bytes)) + (c_stages*(Cs_bytes))
  return total_bytes/(1000)

# %%
BM,BK,BN = 128,32,128

total_bytes = get_smem_kilobytes(BM,BN,BK,bk_stages,c_stages)

# %%
total_bytes
# Out:
# 98.304
