# %%
import cutlass
import torch
import cutlass.cute as cute
import dense_gemm

# %%
seconds = 725.5679965019226*1e-6
FLOPs = 2*(4096*4096*4096)

TFLOP = (FLOPs/(seconds*1e12))

# %%
TFLOP
# Out:
# 189.42256843550823
