# %%
import torch

# %%
import torch

A_fp16 = torch.randn((16,16), device="cuda", dtype=torch.float16)
B_fp16 = torch.randn((16,16), device="cuda", dtype=torch.float16)

A = A_fp16.to(torch.float8_e4m3fn)
B = B_fp16.to(torch.float8_e4m3fn)

C = torch.zeros((16,16), device="cuda", dtype=torch.float16)

# %%
C = torch.matmul(A,B)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 C = torch.matmul(A,B)
#
# NotImplementedError: "addmm_cuda" not implemented for 'Float8_e4m3fn'
