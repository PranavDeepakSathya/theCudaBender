# %%
Qs=1024
Ks = 1024 
Vs=9216 
Qs_bar=17408 
KVs_bar = 17424

# %%
Qs_bytes = 128*256*2

# %%
Qs + Qs_bytes
# Out:
# 66560

# %%
Vs_bytes = 128*32*2

# %%
Vs + Vs_bytes
# Out:
# 17408

# %%
max(Qs+Qs_bytes,Vs+Vs_bytes)
# Out:
# 66560
