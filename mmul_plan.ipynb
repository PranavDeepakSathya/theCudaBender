# %%
import numpy as np

# %%
#okay, now, we gotta figure 
warp_shape = (16,16,8)#m,k,n
n_producer_warps = 1
n_consumer_warps = 16
n_sms = 170 
sm_shape = n_consumer_warps *np.array(warp_shape)

# %%
sm_shape
p_cons_sm_shape = 2*sm_shape
p_cons_sm_shape
# Out:
# array([512, 512, 256])

# %%
#you know what forget about sm paralellism and all that, let us drop 16 warps and just write a normal ass matmul
