# %%
from layout_module import Layout, NestedTuple,Pointed
from layout_module import layout_algebra as la
from layout_module import flat_algebra as fa
from functools import reduce
from operator import mul

# %%
A_shape = (6,6)
A_stride = (6,1)
B_shape = (12,(3,6))

B_stride = (1,(72,12))

A = Layout(NestedTuple.from_literal(A_shape), NestedTuple.from_literal(A_stride))
B = Layout(NestedTuple.from_literal(B_shape), NestedTuple.from_literal(B_stride))

A_mor = la.construct_morphism(A)
B_mor = la.construct_morphism(B)

# %%
A_mor.draw()
B_mor.draw()

# %%
A_composed = la.compose(A,B)

# %%
A_composed
# Out:
# Layout(shape=((2, 3), 6), stride=((6, 72), 1))

# %%
A_composed_morphism = la.construct_morphism(A_composed)

# %%
A_composed_morphism.draw()

# %%
A_shape = (4,8)
A_stride = (1,4)

B_shape = (2,2)
B_stride = (1,4)

A = Layout(NestedTuple.from_literal(A_shape), NestedTuple.from_literal(A_stride))
B = Layout(NestedTuple.from_literal(B_shape), NestedTuple.from_literal(B_stride))

Tiled_layout = la.divide(A,B)

# %%
Tiled_layout.coalesce()
# Out:
# Layout(shape=(2, 2, 2, 4), stride=(1, 4, 2, 8))

# %%
A_shape = (2,2)
A_stride = (5,10)

B_shape = (3,5)
B_stride = (5,1)

A = Layout(NestedTuple.from_literal(A_shape), NestedTuple.from_literal(A_stride))
B = Layout(NestedTuple.from_literal(B_shape), NestedTuple.from_literal(B_stride))

Tiled_layout = la.product(A,B)

# %%
Tiled_layout
# Out:
# Layout(shape=((2, 2), (3, 5)), stride=((5, 10), (20, 1)))
