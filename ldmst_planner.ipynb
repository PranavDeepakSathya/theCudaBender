# %%
"""
Docstring for ldmst_planner.ipynb

there are many things to consider for the instruction ld_matrix, and st_matrix over a group of warps in an sm.

first is smem shape, (sA,sB)
next is smem layout, (rowMaj,colMaj) 
then is the warp shape, (wA,wB)
then the warp layout (rowMaj, colMaj)
the warp layout, will tell us, the co-ordinate mapping (wx0,wx1) --> w_id. 
a triple (nX(the x of the ldmst instruction/num_regs),ldmst_atom_shape,lane_layout:rowMaj/colMaj)
where nX = 1 is compatible with ldmst_atom_shape = (8,8)
nx = 2 is compatible with ldmst_atom_shape (8,16),(16,8) 
nx = 4 is comaptible with ldmst_atom_shape (8,32), (16,16), (32,8). 
then the lane layout (rowMaj, colMaj)


 
"""
# Out:
# '\nDocstring for ldmst_planner.ipynb\n\nthere are many things to consider for the instruction ld_matrix, and st_matrix over a group of warps in an sm.\n\nfirst is smem shape, (sA,sB)\nnext is smem layout, (rowMaj,colMaj) \nthen is the warp shape, (wA,wB)\nthen the warp layout (rowMaj, colMaj)\nthe warp layout, will tell us, the co-ordinate mapping (wx0,wx1) --> w_id. \na triple (nX(the x of the ldmst instruction/num_regs),ldmst_atom_shape,lane_layout:rowMaj/colMaj)\nwhere nX = 1 is compatible with ldmst_atom_shape = (8,8)\nnx = 2 is compatible with ldmst_atom_shape (8,16),(16,8) \nnx = 4 is comaptible with ldmst_atom_shape (8,32), (16,16), (32,8). \n\n\n'
